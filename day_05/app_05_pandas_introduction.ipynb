# %%
# importing numpy package
import numpy as np

# importing system module
import sys

# declaring a list of 1000 elements
S= range(1000)

# printing size of each element of the list
print("Size of each element of list in bytes: ",sys.getsizeof(S))

# printing size of the whole list
print("Size of the whole list in bytes: ",sys.getsizeof(S)*len(S))

# declaring a Numpy array of 1000 elements
D= np.arange(1000)

# printing size of each element of the Numpy array
print("Size of each element of the Numpy array in bytes: ",D.itemsize)

# printing size of the whole Numpy array
print("Size of the whole Numpy array in bytes: ",D.size*D.itemsize)
# Out:
# Size of each element of list in bytes:  48
# Size of the whole list in bytes:  48000
# Size of each element of the Numpy array in bytes:  4
# Size of the whole Numpy array in bytes:  4000

# %%
# importing required packages
import numpy
import time

# size of arrays and lists
size = 1000000

# declaring lists
list1 = range(size)
list2 = range(size)

# declaring arrays
array1 = numpy.arange(size)
array2 = numpy.arange(size)

# capturing time before the multiplication of Python lists
initialTime = time.time()

# multiplying elements of both the lists and stored in another list
resultantList = [(a * b) for a, b in zip(list1, list2)]

# calculating execution time
print("Time taken by Lists to perform multiplication:",
	(time.time() - initialTime),
	"seconds")

# capturing time before the multiplication of Numpy arrays
initialTime = time.time()

# multiplying elements of both the Numpy arrays and stored in another Numpy array
resultantArray = array1 * array2

# calculating execution time
print("Time taken by NumPy Arrays to perform multiplication:",
	(time.time() - initialTime),
	"seconds")
# Out:
# Time taken by Lists to perform multiplication: 0.17701077461242676 seconds
# Time taken by NumPy Arrays to perform multiplication: 0.001992940902709961 seconds

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Purushotham\Desktop\oracle\day_05\case\students.csv")

# %%
df
# Out:
#        name  age   regid  phy  chem  math  bio  avg  rank
# 0     Vijay   14  HPE001   99    98    97   36    0     0
# 1     Aryan   14  HPE002   98    61    93   96    0     0
# 2      Muni   14  HPE003   97    98    77   94    0     0
# 3      Abhi   14  HPE004   86    93    97   95    0     0
# 4   Hemanth   14  HPE005   94    91    93   96    0     0
# 5     Grace   14  HPE006   94    65    46   67    0     0
# 6    Ankita   14  CAP007   99    99    99   99    0     0
# 7      John   14  HPE008   96    93    77   95    0     0
# 8     Chris   14  HPE009   54    91    43   96    0     0
# 9     Grace   14  ORA006   94    95    96   87    0     0
# 10   Ankita   14  INF007   99    99    99   99    0     0

# %%
df.head()
# Out:
#       name  age   regid  phy  chem  math  bio  avg  rank
# 0    Vijay   14  HPE001   99    98    97   36    0     0
# 1    Aryan   14  HPE002   98    61    93   96    0     0
# 2     Muni   14  HPE003   97    98    77   94    0     0
# 3     Abhi   14  HPE004   86    93    97   95    0     0
# 4  Hemanth   14  HPE005   94    91    93   96    0     0

# %%
df.tail()
# Out:
#       name  age   regid  phy  chem  math  bio  avg  rank
# 6   Ankita   14  CAP007   99    99    99   99    0     0
# 7     John   14  HPE008   96    93    77   95    0     0
# 8    Chris   14  HPE009   54    91    43   96    0     0
# 9    Grace   14  ORA006   94    95    96   87    0     0
# 10  Ankita   14  INF007   99    99    99   99    0     0

# %%
df.columns
# Out:
# Index(['name', 'age', 'regid', 'phy', 'chem', 'math', 'bio', 'avg', 'rank'], dtype='object')

# %%
df.shape
# Out:
# (11, 9)

# %%
df['name']
# Out:
# 0       Vijay
# 1       Aryan
# 2        Muni
# 3        Abhi
# 4     Hemanth
# 5       Grace
# 6      Ankita
# 7        John
# 8       Chris
# 9       Grace
# 10     Ankita
# Name: name, dtype: object

# %%
df[['age', 'regid', 'name']]
# Out:
#     age   regid     name
# 0    14  HPE001    Vijay
# 1    14  HPE002    Aryan
# 2    14  HPE003     Muni
# 3    14  HPE004     Abhi
# 4    14  HPE005  Hemanth
# 5    14  HPE006    Grace
# 6    14  CAP007   Ankita
# 7    14  HPE008     John
# 8    14  HPE009    Chris
# 9    14  ORA006    Grace
# 10   14  INF007   Ankita

# %%
df['newcol'] = df['phy'] + df['math']

# %%
df
# Out:
#        name  age   regid  phy  chem  math  bio  avg  rank  newcol
# 0     Vijay   14  HPE001   99    98    97   36    0     0     196
# 1     Aryan   14  HPE002   98    61    93   96    0     0     191
# 2      Muni   14  HPE003   97    98    77   94    0     0     174
# 3      Abhi   14  HPE004   86    93    97   95    0     0     183
# 4   Hemanth   14  HPE005   94    91    93   96    0     0     187
# 5     Grace   14  HPE006   94    65    46   67    0     0     140
# 6    Ankita   14  CAP007   99    99    99   99    0     0     198
# 7      John   14  HPE008   96    93    77   95    0     0     173
# 8     Chris   14  HPE009   54    91    43   96    0     0      97
# 9     Grace   14  ORA006   94    95    96   87    0     0     190
# 10   Ankita   14  INF007   99    99    99   99    0     0     198

# %%
df.drop('newcol', axis=1)
# Out:
#        name  age   regid  phy  chem  math  bio  avg  rank
# 0     Vijay   14  HPE001   99    98    97   36    0     0
# 1     Aryan   14  HPE002   98    61    93   96    0     0
# 2      Muni   14  HPE003   97    98    77   94    0     0
# 3      Abhi   14  HPE004   86    93    97   95    0     0
# 4   Hemanth   14  HPE005   94    91    93   96    0     0
# 5     Grace   14  HPE006   94    65    46   67    0     0
# 6    Ankita   14  CAP007   99    99    99   99    0     0
# 7      John   14  HPE008   96    93    77   95    0     0
# 8     Chris   14  HPE009   54    91    43   96    0     0
# 9     Grace   14  ORA006   94    95    96   87    0     0
# 10   Ankita   14  INF007   99    99    99   99    0     0

# %%
df.loc[0]
# Out:
# name       Vijay
# age           14
# regid     HPE001
# phy           99
# chem          98
# math          97
# bio           36
# avg            0
# rank           0
# newcol       196
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# name       Vijay
# age           14
# regid     HPE001
# phy           99
# chem          98
# math          97
# bio           36
# avg            0
# rank           0
# newcol       196
# Name: 0, dtype: object

# %%
df.iloc[[1, 4, 7, 10]]
# Out:
#        name  age   regid  phy  chem  math  bio  avg  rank  newcol
# 1     Aryan   14  HPE002   98    61    93   96    0     0     191
# 4   Hemanth   14  HPE005   94    91    93   96    0     0     187
# 7      John   14  HPE008   96    93    77   95    0     0     173
# 10   Ankita   14  INF007   99    99    99   99    0     0     198

# %%
df.drop(10)
# Out:
#       name  age   regid  phy  chem  math  bio  avg  rank  newcol
# 0    Vijay   14  HPE001   99    98    97   36    0     0     196
# 1    Aryan   14  HPE002   98    61    93   96    0     0     191
# 2     Muni   14  HPE003   97    98    77   94    0     0     174
# 3     Abhi   14  HPE004   86    93    97   95    0     0     183
# 4  Hemanth   14  HPE005   94    91    93   96    0     0     187
# 5    Grace   14  HPE006   94    65    46   67    0     0     140
# 6   Ankita   14  CAP007   99    99    99   99    0     0     198
# 7     John   14  HPE008   96    93    77   95    0     0     173
# 8    Chris   14  HPE009   54    91    43   96    0     0      97
# 9    Grace   14  ORA006   94    95    96   87    0     0     190

# %%
minidf = df[['phy','chem','bio','math']]

# %%
minidf
# Out:
#     phy  chem  bio  math
# 0    99    98   36    97
# 1    98    61   96    93
# 2    97    98   94    77
# 3    86    93   95    97
# 4    94    91   96    93
# 5    94    65   67    46
# 6    99    99   99    99
# 7    96    93   95    77
# 8    54    91   96    43
# 9    94    95   87    96
# 10   99    99   99    99

# %%
minidf.describe()
# Out:
#              phy       chem        bio       math
# count  11.000000  11.000000  11.000000  11.000000
# mean   91.818182  89.363636  87.272727  83.363636
# std    13.098230  13.403527  19.256640  20.766669
# min    54.000000  61.000000  36.000000  43.000000
# 25%    94.000000  91.000000  90.500000  77.000000
# 50%    96.000000  93.000000  95.000000  93.000000
# 75%    98.500000  98.000000  96.000000  97.000000
# max    99.000000  99.000000  99.000000  99.000000

# %%
minidf.mean()
# Out:
# phy     91.818182
# chem    89.363636
# bio     87.272727
# math    83.363636
# dtype: float64

# %%
minidf.mean(axis=1)
# Out:
# 0     82.50
# 1     87.00
# 2     91.50
# 3     92.75
# 4     93.50
# 5     68.00
# 6     99.00
# 7     90.25
# 8     71.00
# 9     93.00
# 10    99.00
# dtype: float64

# %%
minidf.max()
# Out:
# phy     99
# chem    99
# bio     99
# math    99
# dtype: int64

# %%
minidf.min()
# Out:
# phy     54
# chem    61
# bio     36
# math    43
# dtype: int64

# %%
df
# Out:
#        name  age   regid  phy  chem  math  bio  avg  rank  newcol
# 0     Vijay   14  HPE001   99    98    97   36    0     0     196
# 1     Aryan   14  HPE002   98    61    93   96    0     0     191
# 2      Muni   14  HPE003   97    98    77   94    0     0     174
# 3      Abhi   14  HPE004   86    93    97   95    0     0     183
# 4   Hemanth   14  HPE005   94    91    93   96    0     0     187
# 5     Grace   14  HPE006   94    65    46   67    0     0     140
# 6    Ankita   14  CAP007   99    99    99   99    0     0     198
# 7      John   14  HPE008   96    93    77   95    0     0     173
# 8     Chris   14  HPE009   54    91    43   96    0     0      97
# 9     Grace   14  ORA006   94    95    96   87    0     0     190
# 10   Ankita   14  INF007   99    99    99   99    0     0     198

# %%
df['avg'] = df[['phy','chem','bio','math']].mean(axis=1)

# %%
df
# Out:
#        name  age   regid  phy  chem  math  bio    avg  rank  newcol
# 0     Vijay   14  HPE001   99    98    97   36  82.50     0     196
# 1     Aryan   14  HPE002   98    61    93   96  87.00     0     191
# 2      Muni   14  HPE003   97    98    77   94  91.50     0     174
# 3      Abhi   14  HPE004   86    93    97   95  92.75     0     183
# 4   Hemanth   14  HPE005   94    91    93   96  93.50     0     187
# 5     Grace   14  HPE006   94    65    46   67  68.00     0     140
# 6    Ankita   14  CAP007   99    99    99   99  99.00     0     198
# 7      John   14  HPE008   96    93    77   95  90.25     0     173
# 8     Chris   14  HPE009   54    91    43   96  71.00     0      97
# 9     Grace   14  ORA006   94    95    96   87  93.00     0     190
# 10   Ankita   14  INF007   99    99    99   99  99.00     0     198

# %%
df['rank'] = df['avg'].rank()

# %%
df
# Out:
#        name  age   regid  phy  chem  math  bio    avg  rank  newcol
# 0     Vijay   14  HPE001   99    98    97   36  82.50   3.0     196
# 1     Aryan   14  HPE002   98    61    93   96  87.00   4.0     191
# 2      Muni   14  HPE003   97    98    77   94  91.50   6.0     174
# 3      Abhi   14  HPE004   86    93    97   95  92.75   7.0     183
# 4   Hemanth   14  HPE005   94    91    93   96  93.50   9.0     187
# 5     Grace   14  HPE006   94    65    46   67  68.00   1.0     140
# 6    Ankita   14  CAP007   99    99    99   99  99.00  10.5     198
# 7      John   14  HPE008   96    93    77   95  90.25   5.0     173
# 8     Chris   14  HPE009   54    91    43   96  71.00   2.0      97
# 9     Grace   14  ORA006   94    95    96   87  93.00   8.0     190
# 10   Ankita   14  INF007   99    99    99   99  99.00  10.5     198

# %%
df['rank'] = df['avg'].rank(ascending=False)

# %%
df
# Out:
#        name  age   regid  phy  chem  math  bio    avg  rank  newcol
# 0     Vijay   14  HPE001   99    98    97   36  82.50   9.0     196
# 1     Aryan   14  HPE002   98    61    93   96  87.00   8.0     191
# 2      Muni   14  HPE003   97    98    77   94  91.50   6.0     174
# 3      Abhi   14  HPE004   86    93    97   95  92.75   5.0     183
# 4   Hemanth   14  HPE005   94    91    93   96  93.50   3.0     187
# 5     Grace   14  HPE006   94    65    46   67  68.00  11.0     140
# 6    Ankita   14  CAP007   99    99    99   99  99.00   1.5     198
# 7      John   14  HPE008   96    93    77   95  90.25   7.0     173
# 8     Chris   14  HPE009   54    91    43   96  71.00  10.0      97
# 9     Grace   14  ORA006   94    95    96   87  93.00   4.0     190
# 10   Ankita   14  INF007   99    99    99   99  99.00   1.5     198

# %%
df['rank'] = df['avg'].rank(ascending=False, method='dense')

# %%
df
# Out:
#        name  age   regid  phy  chem  math  bio    avg  rank  newcol
# 0     Vijay   14  HPE001   99    98    97   36  82.50   8.0     196
# 1     Aryan   14  HPE002   98    61    93   96  87.00   7.0     191
# 2      Muni   14  HPE003   97    98    77   94  91.50   5.0     174
# 3      Abhi   14  HPE004   86    93    97   95  92.75   4.0     183
# 4   Hemanth   14  HPE005   94    91    93   96  93.50   2.0     187
# 5     Grace   14  HPE006   94    65    46   67  68.00  10.0     140
# 6    Ankita   14  CAP007   99    99    99   99  99.00   1.0     198
# 7      John   14  HPE008   96    93    77   95  90.25   6.0     173
# 8     Chris   14  HPE009   54    91    43   96  71.00   9.0      97
# 9     Grace   14  ORA006   94    95    96   87  93.00   3.0     190
# 10   Ankita   14  INF007   99    99    99   99  99.00   1.0     198

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(df['regid'], df['avg'], color='r')
plt.show()

# %%
with pd.ExcelWriter("classreport.xlsx") as target:
    df.to_excel(target)
